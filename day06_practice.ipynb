# %% [markdown]
# # LeetCode Hot 100 - Day 06 练习题纯享版
#
# 本文件只保留完整题目和空代码框，不含提示、过程、测试与参考答案。请在学完当天内容后独立重写。

# %% [markdown]
# # 题目 1：合并两个有序链表
#
# LeetCode 21. Merge Two Sorted Lists
#
# ## 题目描述（改写版）
#
# 给你两个按非递减顺序排列的单链表 `list1` 和 `list2`。把它们的节点重新连接成一条同样有序的链表，并返回新链表头节点。
#
# ### 输入、输出与限制
#
# - 两个头节点都可能是 `None`。
# - 可以复用原链表节点，不必复制节点值。
# - 输入中允许出现重复值，输出仍保持非递减顺序。
#
# ### 示例
#
# 输入 `1 -> 2 -> 4` 和 `1 -> 3 -> 4`，输出 `1 -> 1 -> 2 -> 3 -> 4 -> 4`。

# %%
# 题目：合并两个有序链表
# 解法：双指针归并（Two-Pointer Merge）
# 输入：两个可能为空、按非递减顺序排列的链表头节点 list1、list2。
# 目标：复用节点，把它们合成一条有序链表。
# 输出：返回合并后的头节点。
# 注意：相等时取哪边都可以；一条走完后接上另一条的剩余部分。

def merge_two_lists(list1, list2):
    pass

# %% [markdown]
# # 题目 2：两数相加
#
# LeetCode 2. Add Two Numbers
#
# ## 题目描述（改写版）
#
# 两个非负整数分别用两条链表表示。每个节点保存一位数字，并且数字按个位、十位、百位的顺序逆序存放。请计算两数之和，并用相同的逆序链表形式返回。
#
# ### 输入、输出与限制
#
# - 两条链表都非空，每个节点值在 0 到 9 之间。
# - 除数字 0 本身外，不会有多余的前导零。
# - 两数位数可以不同，最后可能多出一个进位节点。
#
# ### 示例
#
# `2 -> 4 -> 3` 表示 342，`5 -> 6 -> 4` 表示 465；和为 807，因此返回 `7 -> 0 -> 8`。

# %%
# 题目：两数相加
# 解法：逐位模拟加法（Digit-by-Digit Addition Simulation）
# 输入：两条逆序保存非负整数各位数字的链表 l1、l2。
# 目标：逐位相加并正确处理进位。
# 输出：返回同样按低位到高位排列的结果链表。
# 注意：链表长度可能不同；最后不能漏掉 carry。

def add_two_numbers(l1, l2):
    pass

# %% [markdown]
# # 题目 3：删除链表的倒数第 N 个节点
#
# LeetCode 19. Remove Nth Node From End of List
#
# ## 题目描述（改写版）
#
# 给你一个单链表头节点 `head` 和整数 `n`。删除链表倒数第 `n` 个节点，并返回删除后的头节点。
#
# ### 输入、输出与限制
#
# - 链表非空，`1 <= n <= 链表长度`。
# - 希望只遍历链表一遍。
# - 被删除的节点可能就是原头节点。
#
# ### 示例
#
# 输入 `1 -> 2 -> 3 -> 4 -> 5`、`n = 2`，删除倒数第二个节点 4，返回 `1 -> 2 -> 3 -> 5`。

# %%
# 题目：删除链表的倒数第 N 个节点
# 解法：固定间距快慢指针（Two Pointers with Fixed Gap）
# 输入：非空链表 head 和合法整数 n。
# 目标：删除倒数第 n 个节点。
# 输出：返回删除后的头节点。
# 注意：可能删除原头节点，建议使用 dummy；目标是一遍扫描。

def remove_nth_from_end(head, n):
    pass

# %% [markdown]
# # 题目 4：环形链表 II
#
# LeetCode 142. Linked List Cycle II
#
# 这是今天的加练题。
#
# ## 题目描述（改写版）
#
# 给你一个可能含环的单链表，返回链表开始进入环的第一个节点；如果没有环，返回 `None`。
#
# ### 输入、输出与限制
#
# - 需要返回节点对象，不是节点值或下标。
# - 节点值可能重复。
# - 不能修改链表，目标额外空间是 `O(1)`。
#
# ### 示例
#
# `3 -> 2 -> 0 -> -4` 的尾节点若指回节点 2，返回节点 2。

# %%
# 题目：环形链表 II
# 解法：Floyd 判环与入口定位（Floyd Cycle Entry Detection）
# 输入：可能为空、可能含环的链表头节点 head。
# 目标：找到链表第一次进入环的节点。
# 输出：返回环入口节点；无环返回 None。
# 注意：先判断并找到相遇点，再从 head 和相遇点同速寻找入口。

def detect_cycle(head):
    pass

# %% [markdown]
# # 完成记录
#
# - 独立写出：
# - 卡住的题：
# - 需要重写的题：
# - 本次完成日期：
